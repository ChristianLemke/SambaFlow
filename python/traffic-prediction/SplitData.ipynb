# %%
# %pwd
# Out:
# 'C:\\Users\\Chrisi\\Desktop\\Studium\\BigDataScience\\sose17-small-data\\python\\traffic-prediction'

# %%
#import src.misc.split_train_valid_notRandom as split
import src.vector_gen.generateCurrentSituationWithTime as gcswt
import src.vector_gen.generateCurrentSituationVector as gcsv
import src.vector_gen.generateTimeInformationVector as gtiv
import src.vector_gen.generateWeatherVectors as gwv
import src.vector_gen.generate_VectorY as vecY
import pandas as pd

trajectories_df = pd.read_csv('../../dataset/training/trajectories(table 5)_training.csv')
weather_df = pd.read_csv('../../dataset/training2/weather (table 7)_training_update.csv')
#x = gwv.generate_TimeInformationCurrentSituationWeatherVectors(trajectories_df,weather_df)
#x = gwv.prepare_weather_df(weather_df)
#x = gtiv.generate_timeInformation_df(trajectories_df)
x = gcsv.generate_x_df(trajectories_df)
y = vecY.generate_VectorY_df(trajectories_df)
#split.split_dataset(df_X=x, df_Y=y  , train=0.9, test=0.1, validation=0.0)
# Out:
# 1092

# %%
y
# Out:
#                      (0, A2)  (0, A3)  (0, B1)  (0, B3)  (0, C1)  (0, C3)  \
# 2016-07-19 00:00:00    46.02    60.06    18.62    70.85    38.50    27.91
# 2016-07-19 02:00:00    37.09    35.27    15.58    67.81     8.36    17.12
# 2016-07-19 04:00:00    48.13    45.88     9.91    96.67    15.55     9.84
# 2016-07-19 06:00:00    46.36   124.66   170.09   145.94   160.38    42.83
# 2016-07-19 08:00:00    81.60   137.38    97.06   125.76   151.39   120.73
# 2016-07-19 10:00:00    78.31    99.04   132.68    98.92   200.92   139.70
# 2016-07-19 12:00:00    60.17   108.74   145.29   144.87   142.74    91.15
# 2016-07-19 14:00:00    65.11    96.92   179.98   159.46   147.60   174.84
# 2016-07-19 16:00:00    59.64   126.61    78.76   116.07   144.70   183.07
# 2016-07-19 18:00:00    85.11    99.14    77.42   108.30   202.21   134.43
# 2016-07-19 20:00:00    87.94   113.02   128.65   112.25   164.91    72.64
# 2016-07-19 22:00:00    46.09   141.25    35.65   149.31    83.33    51.67
# ...

# %%
training_Y = pd.read_csv("src/misc/train_Y.csv", index_col =0)
#validation_Y = pd.read_csv("src/misc/splitting_csv_files/valid_Y.csv", index_col =0)
testing_Y = pd.read_csv("src/misc/test_Y.csv", index_col =0)
training_X = pd.read_csv("src/misc/train_X.csv", index_col =0)
#validation_X = pd.read_csv("src/misc/splitting_csv_files/valid_X.csv", index_col =0)
testing_X = pd.read_csv("src/misc/test_X.csv", index_col =0)

# %%
training_X
# Out:
# Empty DataFrame
# Columns: []
# Index: []
